# %% [markdown]
# # **Summer School Sustainable Digital Finance** - Introduction to Python - 1
# Author: Nicole Bellert - bell@zhaw.ch
#
#
# ---------------------------------------------

# %% [markdown]
# # Jupyter Notebooks
# Jupyter Notebooks use two primary types of cells: Code Cells and Markdown Cells. Code Cells allow users to write and execute Python (or other supported languages) directly within the notebook, displaying output beneath the cell after execution. Markdown Cells, on the other hand, are used for documentation and formatting, supporting plain text, HTML, LaTeX, and Markdown syntax to structure content effectively.
#
# *Code Cells*: By default, a cell in Jupyter is of type Code, as indicated in the dropdown menu under the Help tab. Code Cells are designed for writing and executing code.
#
# *Commenting in Code Cells*: To add comments within a Code Cell, precede the text with a # symbol. Comments provide explanations about the code and are ignored by the interpreter.

# %%
# This is a comment, the interpreter ignores everything within the row after the # symbol
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %% [markdown]
# *Markdown Cells*: While comments can be added in Code Cells, they are limited in formatting. For structured text, headings, or detailed explanations, use Markdown Cells. To switch a cell to Markdown, select Markdown from the dropdown menu under the Help tab.
#
# Markdown supports rich formatting, including bold, italics, lists, and inline code. For reference, you can use an online Markdown Cheat Sheet (https://www.markdownguide.org/cheat-sheet/).
#
# --------------------------

# %% [markdown]
# # Introduction to Python: More Than Just a Calculator
#
# Python can be thought of as a **powerful calculator** that allows us to perform a wide range of mathematical operations with ease. At its simplest, Python can handle basic arithmetic:
#
# ```python
# # Basic Arithmetic Operations
# print(2 + 3)    # Output: 5
# print(10 - 4)   # Output: 6
# print(6 * 7)    # Output: 42
# print(8 / 2)    # Output: 4.0

# %%
print(2+3)
# Out:
# 5

# %%
4*9
# Out:
# 36

# %%
3**2
# Out:
# 9

# %% [markdown]
# In Python, basic arithmetic operations like addition, subtraction, multiplication, and division are built-in and can be used without any extra steps. However, for more complex mathematical operations, such as computing square roots, logarithms, or exponentiation with natural bases, Python requires specialized functions. These functions are not included by default to keep Python lightweight and efficient. Instead, they are provided in the math module, which we can access by importing it using *import math*. This module contains a variety of mathematical functions, constants, and utilities that extend Python’s capabilities beyond simple calculations, making it essential for scientific and financial computations.
#
# *Typical Execution of Code:*
# ```python
# # Mathematical Functions imported from a library of functions *math*
# import math
# print(math.sqrt(16))    # Output: 4.0
# print(math.exp(2))      # Output: 7.38905609893065
# print(math.log(10))     # Output: 2.302585092994046

# %% [markdown]
# First, try running a function without importing the math module:

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# If you have not imported the math module, yet, you will get an error.

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.log(10)
# Out:
# 2.302585092994046

# %% [markdown]
# ## Understanding Lists in Python
# A list is one of the most fundamental and flexible data structures in Python. It allows you to store multiple values in a single variable, making it essential for handling datasets, computations, and iterative tasks. Lists can contain numbers, strings, or even other lists, and they support operations like indexing, slicing, sorting, and appending new elements. Unlike arrays in some other programming languages, Python lists are dynamic, meaning they can grow or shrink as needed.
#
# ```python
# # Creating a list of numbers
# numbers = [53, 50, 45, 70, 62, 56, 80]
#
# # Accessing elements
# print(numbers[0])
# print(numbers[-1])
#
# # Sorting the list
# numbers.sort()
#
# print(numbers)

# %%
# Creating a list of numbers
numbers = [53, 50, 45, 70, 62, 56, 80]

# %%
# Accessing elements
print(numbers[0])  
print(numbers[-1])
# Out:
# 53
# 80

# %%
# Sorting the list
numbers.sort()

print(numbers)
# Out:
# [45, 50, 53, 56, 62, 70, 80]

# %% [markdown]
# ```python
# # Calculate Mean (Average)
# mean_value = np.mean(numbers)
# print(f"Mean (Average): {mean_value}")
#
# # Calculate Median
# median_value = np.median(numbers)
# print(f"Median: {median_value}")
#
# # Calculate First Quartile (Q1) and Third Quartile (Q3)
# q1 = np.percentile(numbers, 25)  # 25th percentile (Q1)
# q3 = np.percentile(numbers, 75)  # 75th percentile (Q3)
# print(f"First Quartile (Q1): {q1:.2f}")
# print(f"Third Quartile (Q3): {q3:.2f}")
#
# # Calculate Sample Variance (unbiased estimator)
# sample_variance = np.var(numbers, ddof=1)  # ddof=1 ensures sample variance
# print(f"Sample Variance: {sample_variance}")

# %%
# Calculate Mean (Average)
import numpy as np
mean_value = np.mean(numbers)
print(f"Mean (Average): {mean_value}")
# Out:
# Mean (Average): 59.42857142857143

# %%
# Calculate Median
median_value = np.median(numbers)
print(f"Median: {median_value}")
# Out:
# Median: 56.0

# %%
# Calculate First Quartile (Q1) and Third Quartile (Q3)
q1 = np.percentile(numbers, 25)  # 25th percentile (Q1)
q3 = np.percentile(numbers, 75)  # 75th percentile (Q3)
print(f"First Quartile (Q1): {q1:.2f}")
print(f"Third Quartile (Q3): {q3:.2f}")
# Out:
# First Quartile (Q1): 51.50
# Third Quartile (Q3): 66.00

# %%
# Calculate Sample Variance (unbiased estimator)
sample_variance = np.var(numbers, ddof=1)  # ddof=1 ensures sample variance
print(f"Sample Variance: {sample_variance}")
# Out:
# Sample Variance: 148.61904761904762

# %% [markdown]
# ## 1. Data Analysis and Visualization:
#
# Python provides powerful libraries for both data analysis and visualization, making it an ideal tool for empirical research. Among these, Matplotlib and Seaborn are two essential libraries for creating high-quality visualizations. Matplotlib is a versatile library that allows users to create a wide range of static, animated, and interactive plots, making it the foundation of Python’s visualization ecosystem. On top of that, Seaborn builds on Matplotlib, offering a more intuitive interface and beautiful default styles for statistical visualizations, such as histograms, box plots, and regression plots.

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style for better aesthetics
sns.set_style("darkgrid")

# Generate a sample dataset
np.random.seed(42)  # For reproducibility
data = pd.DataFrame({
    "x": np.linspace(1, 100, 100),  # A simple range
    "y": np.linspace(1, 100, 100) + np.random.normal(0, 10, 100),  # Adding some noise
    "category": np.random.choice(["A", "B", "C"], 100)  # Categorical variable
})
# Display the first few rows of the dataset
#print(data.head())
data.head()
# Out:
#      x          y category
# 0  1.0   5.967142        A
# 1  2.0   0.617357        B
# 2  3.0   9.476885        A
# 3  4.0  19.230299        A
# 4  5.0   2.658466        C

# %%
## ---- Matplotlib Example: Basic Line Plot ---- ##
plt.figure(figsize=(8,5))
plt.plot(data["x"], data["y"], color="blue", linestyle="--", marker="o", label="Noisy Linear Data")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Matplotlib: Basic Line Plot Example")
plt.legend()
plt.show()

## ---- Seaborn Example: Scatter Plot with Regression Line ---- ##
plt.figure(figsize=(8,5))
sns.regplot(x="x", y="y", data=data, scatter_kws={"color": "darkblue"}, line_kws={"color": "red"})
plt.title("Seaborn: Regression Line with Scatter Plot")
plt.show()

## ---- Seaborn Example: Box Plot ---- ##
plt.figure(figsize=(8,5))
sns.boxplot(x="category", y="y", data=data, palette="coolwarm")
plt.title("Seaborn: Box Plot of Y by Category")
plt.show()

## ---- Seaborn Example: Distribution Plot ---- ##
plt.figure(figsize=(8,5))
sns.histplot(data["y"], kde=True, bins=20, color="green")
plt.title("Seaborn: Distribution of Y with KDE")
plt.xlabel("Y values")
plt.show()
# Out:
# C:\Users\bell\AppData\Local\Temp\ipykernel_47088\1330638719.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="category", y="y", data=data, palette="coolwarm")

# %% [markdown]
# ## 2. Statistical and Econometric Modeling
#
# Statistical and econometric modeling relies on random numbers, probability distributions, and probability calculations to analyze real-world data and test economic theories. In empirical research, we often work with random variables that follow specific probability distributions, such as the normal distribution (e.g., modeling stock returns), the Poisson distribution (e.g., modeling the number of customer arrivals), or the binomial distribution (e.g., modeling success/failure outcomes). These distributions help us simulate real-world scenarios, generate synthetic data, and quantify uncertainty. Using Python, we can draw random samples from these distributions and compute key probabilities. For instance, we can answer questions like: What is the probability that a stock return is below a certain threshold? or How likely is it that a firm will experience a given number of customer visits in an hour? Python's numpy and scipy.stats libraries provide powerful tools to generate random numbers, calculate probabilities, and estimate statistical properties, making it an essential toolkit for econometric modeling and hypothesis testing. Let’s explore some examples in Python!
#
# ```python
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt
#
# # 1. Generate random numbers from a normal distribution (mean=0, std=1)
# normal_data = np.random.normal(loc=0, scale=1, size=1000)
#
# # 2. Probability of a value being <= 1.5 in a standard normal distribution
# prob = stats.norm.cdf(1.5)  # P(X ≤ 1.5)
# print(f"Probability P(X ≤ 1.5) in N(0,1): {prob:.4f}")
#
# # 3. Probability of a Poisson event (λ=3) being exactly 2
# poisson_prob = stats.poisson.pmf(2, mu=3)  # P(X = 2)
# print(f"Probability of observing exactly 2 events when λ=3: {poisson_prob:.4f}")
#
# # 4. Visualizing probability distributions
# x = np.linspace(-4, 4, 1000)
# plt.plot(x, stats.norm.pdf(x), label="Normal Distribution (μ=0, σ=1)", color='blue')
# plt.xlabel("X values")
# plt.ylabel("Probability Density")
# plt.title("Probability Density Function of a Normal Distribution")
# plt.legend()
# plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# 1. Generate random numbers from a normal distribution (mean=0, std=1)
normal_data = np.random.normal(loc=0, scale=1, size=1000)

# %%
# 2a. Probability of a value being <= 1.5 in a standard normal distribution
prob_a = stats.norm.cdf(1.5)  
print(f"Probability P(X <= 1.5) in N(0,1): {prob_a}")

# 2b. Probability of a value being >= 2 in a standard normal distribution
prob_b = 1 - stats.norm.cdf(2) 
print(f"Probability P(X >= 2) in N(0,1): {prob_b}")

# 2c. Probability of a value being <= 1.5 but also >= 2 in a standard normal distribution
prob_c = stats.norm.cdf(2) - stats.norm.cdf(1.5) 
print(f"Probability P(1.5 <= X <= 2) in N(0,1): {prob_c}")
# Out:
# Probability P(X <= 1.5) in N(0,1): 0.9331927987311419
# Probability P(X >= 2) in N(0,1): 0.02275013194817921
# Probability P(1.5 <= X <= 2) in N(0,1): 0.04405706932067888

# %%
# 3. Visualizing probability distributions
x = np.linspace(-4, 4, 1000)
plt.plot(x, stats.norm.pdf(x), label="Normal Distribution (μ=0, σ=1)", color='blue')
plt.xlabel("X values")
plt.ylabel("Probability Density")
plt.title("Probability Density Function of a Normal Distribution")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Writing Your Own Functions in Python
# Functions are a fundamental part of Python programming, allowing us to reuse code, improve readability, and structure our analysis efficiently. Instead of repeating the same calculations multiple times, we can define a function once and call it whenever needed.
#
# A function is created using the def keyword, followed by a function name and a set of parameters. The function body contains the operations to be performed, and the result is returned using the return statement.
#
# ```python
# # Define a function to calculate the square of a number
# def square(x):
#     return x ** 2
#
# # Using the function
# result = square(4)
# print(f"The square of 4 is: {result}")  # Output: 16

# %%
# Define a function to calculate the square of a number
def square(x):
    return x ** 2

# %%
# Using the function
result = square(4)
print(f"The square of 4 is: {result}")  # Output: 16
# Out:
# The square of 4 is: 16

# %% [markdown]
# ## 4. Introduction to Pandas and Importing Data
# Pandas is a powerful Python library for data manipulation and analysis, widely used in empirical research and econometrics. The core data structure in Pandas is the df, which allows us to store and manipulate tabular data (similar to an Excel spreadsheet or SQL table).
#
# One of the first steps in data analysis is importing data into a df. Pandas makes this easy with built-in functions to read various file formats, including CSV, Excel, JSON, and Stata.

# %%
df = pd.read_stata("data/shp10_health.dta")
df["weight"] = df["weight"].astype(float)
df["female"] = df["female"].replace({0: "M", 1: "F"})
df.head()
# print(df.head())
# print(df.shape)
# Out:
#   idpers  year   age female  satisfaction sports  swiss  married      canton  \
# 0   4101  2010  45.0      M          10.0    yes    1.0      1.0  GE  Geneva
# 1   4102  2010  42.0      F           8.0    0.0    1.0      1.0  GE  Geneva
# 2   4103  2010  19.0      M          10.0    yes    1.0      0.0  GE  Geneva
# 3   4104  2010  17.0      M          11.0    yes    1.0      0.0  GE  Geneva
# 4   4105  2010  14.0      F          11.0    yes    1.0      0.0  GE  Geneva
#
#   nbkid  ... nbdhealthp  doc nbdoccons smoker smokes back sleep_prob  \
# 0   2.0  ...      never  yes       1.0    0.0    NaN  1.0        1.0
# 1   2.0  ...        NaN  yes      15.0    0.0    NaN  1.0        0.0
# 2   2.0  ...      never  yes       1.0    0.0    NaN  1.0        1.0
# 3   2.0  ...      never  0.0       NaN    0.0    NaN  1.0        1.0
# 4   2.0  ...      never  yes       3.0    0.0    NaN  1.0        0.0
#
#   l_lifesat  l_satisfaction       _merge
# 0  2.302585        2.302585  matched (3)
# 1  2.079442        2.079442  matched (3)
# 2  2.302585        2.302585  matched (3)
# 3  2.397895        2.397895  matched (3)
# 4  2.397895        2.397895  matched (3)
#
# [5 rows x 37 columns]

# %%
import statsmodels.api as sm
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11332 entries, 0 to 11331
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idpers          11332 non-null  category
#  1   year            11332 non-null  int16
#  2   age             11330 non-null  category
#  3   female          11332 non-null  object
#  4   satisfaction    7548 non-null   float32
#  5   sports          7544 non-null   category
#  6   swiss           11330 non-null  float32
#  7   married         11326 non-null  float64
#  8   canton          11330 non-null  category
#  9   nbkid           11330 non-null  category
#  10  height          8161 non-null   category
#  11  weight          7475 non-null   float64
#  12  fathinc         2122 non-null   category
#  13  mothinc         2392 non-null   category
#  14  occupa          11320 non-null  category
#  15  inc_net         4996 non-null   category
#  16  hh_inc_net      9976 non-null   category
#  17  educ            10681 non-null  category
#  18  compul          10681 non-null  float32
#  19  appren          10681 non-null  float32
#  20  matura          10681 non-null  float32
#  21  hghvoc          10681 non-null  float32
#  22  university      10681 non-null  float32
#  23  working         7550 non-null   float64
#  24  unemp           7550 non-null   float64
#  25  health          7550 non-null   float32
#  26  sat_healthst    7545 non-null   category
#  27  nbdhealthp      7473 non-null   category
#  28  doc             7533 non-null   category
#  29  nbdoccons       5637 non-null   category
#  30  smoker          7513 non-null   float32
#  31  smokes          1356 non-null   float64
#  32  back            7549 non-null   float32
#  33  sleep_prob      7549 non-null   float32
#  34  l_lifesat       7548 non-null   float32
#  35  l_satisfaction  7548 non-null   float32
#  36  _merge          11332 non-null  category
# dtypes: category(17), float32(13), float64(5), int16(1), object(1)
# memory usage: 1.8+ MB

# %%
df.isna().sum()
# Out:
# idpers               0
# year                 0
# age                  2
# female               0
# satisfaction      3784
# sports            3788
# swiss                2
# married              6
# canton               2
# nbkid                2
# height            3171
# weight            3857
# fathinc           9210
# mothinc           8940
# occupa              12
# inc_net           6336
# hh_inc_net        1356
# educ               651
# compul             651
# appren             651
# matura             651
# hghvoc             651
# university         651
# working           3782
# unemp             3782
# health            3782
# sat_healthst      3787
# nbdhealthp        3859
# doc               3799
# nbdoccons         5695
# smoker            3819
# smokes            9976
# back              3783
# sleep_prob        3783
# l_lifesat         3784
# l_satisfaction    3784
# _merge               0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# idpers            0
# year              0
# age               0
# female            0
# satisfaction      0
# sports            0
# swiss             0
# married           0
# canton            0
# nbkid             0
# height            0
# weight            0
# fathinc           0
# mothinc           0
# occupa            0
# inc_net           0
# hh_inc_net        0
# educ              0
# compul            0
# appren            0
# matura            0
# hghvoc            0
# university        0
# working           0
# unemp             0
# health            0
# sat_healthst      0
# nbdhealthp        0
# doc               0
# nbdoccons         0
# smoker            0
# smokes            0
# back              0
# sleep_prob        0
# l_lifesat         0
# l_satisfaction    0
# _merge            0
# dtype: int64

# %%
# Some data management for sports columns
df['sports'] = df['sports'].astype(bool).astype(int)
df['sports']
# Out:
# 124      0
# 308      1
# 517      1
# 518      0
# 558      1
#         ..
# 10751    1
# 10835    1
# 11091    1
# 11183    0
# 11251    1
# Name: sports, Length: 77, dtype: int64

# %%
#df.describe(include='all')
df.describe()
# Out:
#          year  satisfaction     sports      swiss    married      weight  \
# count    77.0     77.000000  77.000000  77.000000  77.000000   77.000000
# mean   2010.0      8.909091   0.675325   0.948052   0.025974   69.350649
# std       0.0      1.041024   0.471324   0.223377   0.160101   12.702845
# min    2010.0      5.000000   0.000000   0.000000   0.000000   47.000000
# 25%    2010.0      9.000000   0.000000   1.000000   0.000000   61.000000
# 50%    2010.0      9.000000   1.000000   1.000000   0.000000   68.000000
# 75%    2010.0      9.000000   1.000000   1.000000   0.000000   75.000000
# max    2010.0     11.000000   1.000000   1.000000   1.000000  120.000000
#
#           compul     appren     matura     hghvoc  university    working  \
# count  77.000000  77.000000  77.000000  77.000000   77.000000  77.000000
# mean    0.506494   0.233766   0.116883   0.051948    0.090909   0.831169
# std     0.503236   0.426000   0.323388   0.223377    0.289365   0.377059
# min     0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000    0.000000   1.000000
# 50%     1.000000   0.000000   0.000000   0.000000    0.000000   1.000000
# 75%     1.000000   0.000000   0.000000   0.000000    0.000000   1.000000
# max     1.000000   1.000000   1.000000   1.000000    1.000000   1.000000
#
#            unemp     health  smoker     smokes       back  sleep_prob  \
# count  77.000000  77.000000    77.0  77.000000  77.000000    77.00000
# mean    0.051948   4.038961     1.0   9.454545   0.545455     0.38961
# std     0.223377   0.548720     0.0   6.003388   0.501195     0.49086
# min     0.000000   3.000000     1.0   1.000000   0.000000     0.00000
# 25%     0.000000   4.000000     1.0   5.000000   0.000000     0.00000
# 50%     0.000000   4.000000     1.0  10.000000   1.000000     0.00000
# 75%     0.000000   4.000000     1.0  12.000000   1.000000     1.00000
# max     1.000000   5.000000     1.0  25.000000   1.000000     1.00000
#
#        l_lifesat  l_satisfaction
# count  77.000000       77.000000
# mean    2.179459        2.179459
# std     0.128650        0.128650
# min     1.609438        1.609438
# 25%     2.197225        2.197225
# 50%     2.197225        2.197225
# 75%     2.197225        2.197225
# max     2.397895        2.397895

# %%
# Life Satisfaction
plt.figure()
plt.hist(df['satisfaction'])
plt.axvline(df['satisfaction'].mean(), color = 'red', label = 'Average level of Life Satisfaction')
plt.xlabel('Level of Life Satisfaction')
plt.ylabel('Frequency')
plt.xticks(np.arange(1, 12, 1))
plt.legend()
plt.title('Distribution of Life Satisfaction among the sample');

# %%
# Sport
plt.figure()
plt.hist(df['sports'])
plt.xlabel('Sports')
plt.ylabel('Frequency')
plt.xticks(np.arange(1, 2, 1))
plt.title('People engaging in Sports Activity');

# %%
# Avg Satisfaction for people doing and not doing sports
mask1 = (df['sports'] == 1)
df['satisfaction'][mask1].describe()
# Out:
# count    52.000000
# mean      9.000000
# std       0.970142
# min       5.000000
# 25%       9.000000
# 50%       9.000000
# 75%       9.250000
# max      11.000000
# Name: satisfaction, dtype: float64

# %%
mask0 = (df['sports'] == 0)
df['satisfaction'][mask0].describe()
# Out:
# count    25.000000
# mean      8.720000
# std       1.173314
# min       6.000000
# 25%       8.000000
# 50%       9.000000
# 75%       9.000000
# max      11.000000
# Name: satisfaction, dtype: float64

# %%
# Let's plot together
# 1. Hist
plt.figure()
plt.hist(df[mask0]['satisfaction'], label = 'Not Practing Sports')
plt.hist(df[mask1]['satisfaction'], label = 'Practing Sports')
plt.xlabel('Level of Life Satisfaction')
plt.ylabel('Frequency')
plt.xticks(np.arange(1, 12, 1))
plt.legend()
plt.title('Life Satisfaction by Sports Participation');

# %%
# kdeplot (distributions)
plt.figure(figsize=(8, 5))
sns.kdeplot(data=df, x='satisfaction', hue='sports', fill=True, alpha=0.5)
plt.title('Life Satisfaction by Sports Participation')
plt.xlabel('Life Satisfaction')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# #### Define the SLR model
# We want to fit the model:
#
# $$ satisfaction_i = \beta_0 + \beta_1 sports_i + u_i$$

# %%
# Define dependent and independent variables
X = sm.add_constant(df['sports']) 
y = df['satisfaction']

# Fit the model
slr_model = sm.OLS(y, X).fit()
print(slr_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           satisfaction   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.225
# Date:                Fri, 22 Aug 2025   Prob (F-statistic):              0.272
# Time:                        10:19:19   Log-Likelihood:                -111.23
# No. Observations:                  77   AIC:                             226.5
# Df Residuals:                      75   BIC:                             231.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.7200      0.208     41.944      0.000       8.306       9.134
# sports         0.2800      0.253      1.107      0.272      -0.224       0.784
# ==============================================================================
# Omnibus:                       20.082   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.522
# Skew:                          -0.971   Prob(JB):                     3.19e-08
# Kurtosis:                       5.644   Cond. No.                         3.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
